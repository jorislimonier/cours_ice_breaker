# %%
import requests
import os

print(os.environ.get("PROXYCURL_API_KEY"))

PROXYCURL_API_KEY = os.environ.get("PROXYCURL_API_KEY")
headers = {"Authorization": "Bearer " + PROXYCURL_API_KEY}
api_endpoint = "https://nubela.co/proxycurl/api/v2/linkedin"
params = {
    "linkedin_profile_url": "https://linkedin.com/in/jorislimonier",
}
response = requests.get(api_endpoint, params=params, headers=headers)

print(response.json())
# Out:
# 9RYqmUNMLZUckSv-5lxwOQ
# ...

# %%
print(response.json())
# Out:
# {'public_identifier': 'jorislimonier', 'profile_pic_url': 'https://s3.us-west-000.backblazeb2.com/proxycurl/person/jorislimonier/profile?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=0004d7f56a0400b0000000001%2F20240120%2Fus-west-000%2Fs3%2Faws4_request&X-Amz-Date=20240120T172729Z&X-Amz-Expires=3600&X-Amz-SignedHeaders=host&X-Amz-Signature=e6de5bfb13d9fe3357e7af1a10d6802aa40b81231bd8cd5ff33f8c0c811c49a9', 'background_cover_image_url': 'https://s3.us-west-000.backblazeb2.com/proxycurl/person/jorislimonier/cover?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=0004d7f56a0400b0000000001%2F20240120%2Fus-west-000%2Fs3%2Faws4_request&X-Amz-Date=20240120T172729Z&X-Amz-Expires=3600&X-Amz-SignedHeaders=host&X-Amz-Signature=9ce1cc232450558be2f1d7d4473b72139e30eee142736d85a7994cbaa35c2d64', 'first_name': 'Joris', 'last_name': 'LIMONIER', 'full_name': 'Joris LIMONIER', 'follower_count': 745, 'occupation': 'Data Scientist at Framatome', 'headline': '💡 Data Scientist Freelancer 💡 I help your 
# ...

# %%
gist_url = "https://gist.githubusercontent.com/jorislimonier/2b76951b5431c95c8f1c9a9dcc9a6631/raw/69157b0fcfa883086dbe1b8c3c0084c198e8f7d4/linkedin_joris_limonier.json"
gist_response = requests.get(gist_url)
gist_response.json()["full_name"]
# Out:
# 'Joris LIMONIER'
